# %% [markdown]
# # 🧭 Planning Pattern
#
#
# ![image.png](attachment:cde596be-6f8f-4cc6-a78f-c964148fab62.png)
#
# ### **What**
# The **Planning Pattern** enables an agent to decompose a complex goal into a structured sequence of smaller, executable actions.
# Rather than following a fixed workflow, the agent autonomously determines **how** to achieve the **what** (the goal).
#
# ---
#
# ### **How it Works**
# 1. Understands **initial state** and **goal state**.
# 2. **Generates a plan** — a sequence of actions or steps.
# 3. **Executes the plan** while adapting to new information or constraints.
# 4. **Replans dynamically** if obstacles arise (e.g., unavailable resources).
#
# ---

# %%
from typing import Annotated, TypedDict, Any, Optional
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage, RemoveMessage, AnyMessage
from langchain_core.prompts import ChatPromptTemplate

from langgraph.graph import START, END, StateGraph, MessagesState, add_messages
from langgraph.prebuilt import ToolNode
from langgraph.errors import InvalidUpdateError

from IPython.display import display, Image

import operator
from datetime import datetime

from langchain_tavily import TavilySearch

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
    model="/gpfs/projects/bsc02/llm_models/huggingface_models/Qwen3-32B",
    openai_api_key="dummy",  # vLLM doesn't need a real key
    openai_api_base="http://localhost:8002/v1",  # Your forwarded port
    temperature=0.7,
    max_tokens=500
)

# %%
tavily = TavilySearch(max_results=5)

# %% [markdown]
# ### 1. Define Agent State

# %%
# ---------------------- Agent State Definition ----------------------
class AgentState(TypedDict):
    messages: Annotated[list, add_messages]
    music_event_recommendations: Optional[list[str]]
    event_info_list: Optional[list[str]]
    next_node: Optional[str]
    excluded_events: Optional[list[str]]

# %% [markdown]
# ### 2. Define Agent Nodes

# %%
# ---------------------- Node 1: Planner ----------------------
def planner_node(state: AgentState):
    """Generates plan for search and execution."""
    print("\n[PLANNER NODE] - Generating plan...")
    user_query = state["messages"][0].content
    today_date = datetime.now().strftime("%B %d, %Y")

    prompt = (
        f"Today's date is {today_date}. "
        f"You are a helpful planner agent. Create a concise plan to answer the following user query by searching the internet "
        f"and gathering factual details:\n\n"
        f"User Query: {user_query}\n\n"
        f"Keep the plan brief, outlining the steps or information categories to collect."
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    print("[PLANNER NODE] - Plan generated.")
    return {
        "messages": [response],
        "music_event_recommendations": None,
        "event_info_list": None,
        "next_node": "recommendation",
        "excluded_events": state.get("excluded_events", []),
    }

# %%
# ---------------------- Node 2: Recommendation ----------------------
def recommendation_node(state: AgentState):
    """Generates top recommendations (events, topics, etc.) using LLM."""
    print("\n[RECOMMENDATION NODE] - Generating top recommendations...")
    user_query = state["messages"][0].content
    plan_text = state["messages"][-1].content
    today_date = datetime.now().strftime("%B %d, %Y")
    excluded = state.get("excluded_events", [])

    prompt = (
        f"Today's date is {today_date}. "
        f"Based on this plan and user query, recommend 3 specific items (e.g., events, options, results) relevant to the query. "
        f"Do not include any from this exclusion list: {excluded if excluded else 'None'}.\n\n"
        f"User Query: {user_query}\n\n"
        f"Plan:\n{plan_text}\n\n"
        "Return a numbered list of exactly 3 distinct recommendations."
    )
    response = llm.invoke([HumanMessage(content=prompt)])
    recommended_text = response.content.strip()
    recommendations = [line.split(". ", 1)[1] for line in recommended_text.split('\n') if ". " in line]

    print(f"[RECOMMENDATION NODE] - Generated recommendations: {recommendations}")
    return {
        "messages": [AIMessage(content=recommended_text)],
        "music_event_recommendations": recommendations,
        "event_info_list": None,
        "next_node": "lookup",
        "excluded_events": excluded,
    }

# %%
# ---------------------- Node 3: Lookup (with Tavily) ----------------------
def lookup_node(state: AgentState):
    """Searches the web for factual information about recommendations."""
    print("\n[LOOKUP NODE] - Fetching real-world info using Tavily...")
    recommendations = state["music_event_recommendations"]
    event_info_list = []
    excluded = state.get("excluded_events", [])
    today_date = datetime.now().strftime("%B %d, %Y")

    if not recommendations:
        print("[LOOKUP NODE] - No recommendations provided, stopping workflow.")
        return {"next_node": "executor"}

    insufficient = False
    seen = set(excluded)

    for item in recommendations:
        if item in seen:
            print(f"[LOOKUP NODE] - Skipping excluded item: {item}")
            continue

        query = f"{item} {today_date}"
        print(f"[LOOKUP NODE] - Tavily search: {query}")
        try:
            results = tavily.invoke({"query": query})
            if results and "results" in results and results["results"]:
                top_result = results["results"][0]
                info = f"Title: {top_result['title']}\nURL: {top_result['url']}\nSnippet: {top_result['content'][:300]}..."
                event_info_list.append(info)
                print(f"[LOOKUP NODE] - Found info for '{item}'")
            else:
                info = f"No details found for {item}."
                event_info_list.append(info)
                insufficient = True
                seen.add(item)
                print(f"[LOOKUP NODE] - No info found for '{item}', added to excluded list.")
        except Exception as e:
            print(f"[LOOKUP NODE] - Tavily search failed for '{item}': {e}")
            insufficient = True
            seen.add(item)

    next_node = "recommendation" if insufficient else "executor"
    return {
        "messages": [],
        "music_event_recommendations": state["music_event_recommendations"],
        "event_info_list": event_info_list,
        "next_node": next_node,
        "excluded_events": list(seen),
    }

# %%
# ---------------------- Node 4: Executor ----------------------
def executor_node(state: AgentState):
    """Final output generation."""
    print("\n[EXECUTOR NODE] - Generating final summary...")
    recs = state["music_event_recommendations"]
    infos = state["event_info_list"]
    today_date = datetime.now().strftime("%B %d, %Y")

    summary = f"--- Final Results for {today_date} ---\n\n"
    for i, rec in enumerate(recs or []):
        details = infos[i] if infos and i < len(infos) else "No additional info found."
        summary += f"**{i+1}. {rec}**\n{details}\n\n"

    print("[EXECUTOR NODE] - Summary complete.")
    return {
        "messages": [AIMessage(content=summary.strip())],
        "music_event_recommendations": recs,
        "event_info_list": infos,
        "next_node": "executor",
        "excluded_events": state.get("excluded_events", []),
    }

# %%
# ---------------------- Decision Logic ----------------------
def decide_next_node(state):
    """Decide whether to replan or finalize."""
    if state.get("next_node") == "recommendation":
        return "recommendation"
    return "executor"

# %% [markdown]
# ### 3. Build the LangGraph StateGraph

# %%
# ---------------------- Build Graph ----------------------
graph = StateGraph(AgentState)
graph.add_node("planner", planner_node)
graph.add_node("recommendation", recommendation_node)
graph.add_node("lookup", lookup_node)
graph.add_node("executor", executor_node)

graph.add_edge(START, "planner")
graph.add_edge("planner", "recommendation")
graph.add_edge("recommendation", "lookup")
graph.add_conditional_edges("lookup", decide_next_node, {"recommendation": "recommendation", "executor": "executor"})
graph.add_edge("executor", END)

app = graph.compile()

# %%
display(Image(app.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### 4. Run the Agent

# %%
# ---------------------- Run Agent ----------------------
user_input = input("Best irish music events and pubs in Barcelona tonight? ")

# %%
inputs = {
    "messages": [HumanMessage(content=user_input)],
    "music_event_recommendations": None,
    "event_info_list": None,
    "next_node": None,
    "excluded_events": [],
}

# %%
result = app.invoke(inputs)
# Out:
# [PLANNER NODE] - Generating plan...
# [PLANNER NODE] - Plan generated.
#
# [RECOMMENDATION NODE] - Generating top recommendations...
# [RECOMMENDATION NODE] - Generated recommendations: ["The user wants the best Irish music events and pubs in Barcelona tonight, which is February 27, 2026. Since I can't access real-time data, I'll have to rely on existing knowledge and common venues in Barcelona that are known for Irish music.", "The most famous one is *The Irish Pub* in El Raval. They often host live sessions, especially around St. Patrick's Day, but even in February, they might have something going on. I should include that. ", "They're known for traditional music, and it's possible they have a scheduled event tonight. Checking their website or social media would be ideal, but since I can't do that, I'll assume they have regular sessions. ", "They sometimes feature live bands, so maybe there's an event tonight. ", "Let me make sure these are distinct and relevant. I should also mention any possible events, like a traditional music night or a session with a local band. Since it's February 27, maybe they have a special event closer to St. Patrick's Day. ", "Also, include practical details like location and maybe entry info. Let me double-check if these pubs are still operating and if their music nights are consistent. Since it's 2026, some info might have changed, but these are long-standing establishments. ", '**Live Session at The Irish Pub**  ', ' ', ' ', 'No cover charge.  ', '**St. Patrick’s Day Preview at O’Donnell’s Irish Pub**  ']
#
# [LOOKUP NODE] - Fetching real-world info using Tavily...
# [LOOKUP NODE] - Tavily search: The user wants the best Irish music events and pubs in Barcelona tonight, which is February 27, 2026. Since I can't access real-time data, I'll have to rely on existing knowledge and common venues in Barcelona that are known for Irish music. February 27, 2026
# [LOOKUP NODE] - Found info for 'The user wants the best Irish music events and pubs in Barcelona tonight, which is February 27, 2026. Since I can't access real-time data, I'll have to rely on existing knowledge and common venues in Barcelona that are known for Irish music.'
# [LOOKUP NODE] - Tavily search: The most famous one is *The Irish Pub* in El Raval. They often host live sessions, especially around St. Patrick's Day, but even in February, they might have something going on. I should include that.  February 27, 2026
# [LOOKUP NODE] - Found info for 'The most famous one is *The Irish Pub* in El Raval. They often host live sessions, especially around St. Patrick's Day, but even in February, they might have something going on. I should include that. '
# [LOOKUP NODE] - Tavily search: They're known for traditional music, and it's possible they have a scheduled event tonight. Checking their website or social media would be ideal, but since I can't do that, I'll assume they have regular sessions.  February 27, 2026
# [LOOKUP NODE] - Found info for 'They're known for traditional music, and it's possible they have a scheduled event tonight. Checking their website or social media would be ideal, but since I can't do that, I'll assume they have regular sessions. '
# [LOOKUP NODE] - Tavily search: They sometimes feature live bands, so maybe there's an event tonight.  February 27, 2026
# [LOOKUP NODE] - Found info for 'They sometimes feature live bands, so maybe there's an event tonight. '
# [LOOKUP NODE] - Tavily search: Let me make sure these are distinct and relevant. I should also mention any possible events, like a traditional music night or a session with a local band. Since it's February 27, maybe they have a special event closer to St. Patrick's Day.  February 27, 2026
# [LOOKUP NODE] - Found info for 'Let me make sure these are distinct and relevant. I should also mention any possible events, like a traditional music night or a session with a local band. Since it's February 27, maybe they have a special event closer to St. Patrick's Day. '
# [LOOKUP NODE] - Tavily search: Also, include practical details like location and maybe entry info. Let me double-check if these pubs are still operating and if their music nights are consistent. Since it's 2026, some info might have changed, but these are long-standing establishments.  February 27, 2026
# [LOOKUP NODE] - Found info for 'Also, include practical details like location and maybe entry info. Let me double-check if these pubs are still operating and if their music nights are consistent. Since it's 2026, some info might have changed, but these are long-standing establishments. '
# [LOOKUP NODE] - Tavily search: **Live Session at The Irish Pub**   February 27, 2026
# [LOOKUP NODE] - Found info for '**Live Session at The Irish Pub**  '
# [LOOKUP NODE] - Tavily search:   February 27, 2026
# [LOOKUP NODE] - Found info for ' '
# [LOOKUP NODE] - Tavily search:   February 27, 2026
# [LOOKUP NODE] - Found info for ' '
# [LOOKUP NODE] - Tavily search: No cover charge.   February 27, 2026
# [LOOKUP NODE] - Found info for 'No cover charge.  '
# [LOOKUP NODE] - Tavily search: **St. Patrick’s Day Preview at O’Donnell’s Irish Pub**   February 27, 2026
# [LOOKUP NODE] - Found info for '**St. Patrick’s Day Preview at O’Donnell’s Irish Pub**  '
#
# [EXECUTOR NODE] - Generating final summary...
# [EXECUTOR NODE] - Summary complete.

# %%
# Print final answer
print("\n=== FINAL OUTPUT ===")
print(result["messages"][-1].content)
# Out:
# === FINAL OUTPUT ===
# --- Final Results for February 27, 2026 ---
#
# **1. The user wants the best Irish music events and pubs in Barcelona tonight, which is February 27, 2026. Since I can't access real-time data, I'll have to rely on existing knowledge and common venues in Barcelona that are known for Irish music.**
# Title: The Michael Collins Irish Pub: Welcome
# URL: https://michaelcollinspubs.com/
# Snippet: The best Irish Pub in Barcelona! Live Music, Sports, Traditional Irish Music ... 9:00 pm, February 27, 2026 – WOLVES V ASTON VILLA; 11:30 pm, February 27...
#
# **2. The most famous one is *The Irish Pub* in El Raval. They often host live sessions, especially around St. Patrick's Day, but even in February, they might have something going on. I should include that. **
# Title: THE BEST 10 IRISH PUB near EL RAVAL, BARCELONA, SPAIN
# URL: https://www.yelp.com/search?cflt=irish_pubs&find_loc=El+Raval%2C+Barcelona
# Snippet: The Best 10 Irish Pub near El Raval, Barcelona, Spain · 1. Flaherty's Irish Pub Barcelona · 2. Scobies Irish Pub · 3. McCarthy's · 4. Irish Pub Temple Bar · 5. The...
#
# **3. They're known for traditional music, and it's possible they have a scheduled event tonight. Checking their website or social media would be ideal, but since I can't do that, I'll assume they have regular sessions. **
# Title: Event Calendar - Music Center
# URL: https://www.musiccenter.org/event-calendar/
# Snippet: February 2026. February 1 | Sunday. Common Ground: The Music of Górecki and ... February 27 | Friday. Gloria Molina Grand Park's Wellness Break. 12:00 PM....
#
# **4. They sometimes feature live bands, so maybe there's an event tonight. **
# Title: Live Music Calendar - Aster Cafe
# URL: https://astercafe.com/live-music-calendar/
# Snippet: Friday, February 27, 2026. ​. 8:30pm-10:30pm. ​. 125 SE Main St., Minneapolis ... There's something so powerful about sharing a moment or emotion through a...
#
# **5. Let me make sure these are distinct and relevant. I should also mention any possible events, like a traditional music night or a session with a local band. Since it's February 27, maybe they have a special event closer to St. Patrick's Day. **
# Title: St. Patrick's Celebrations - Edgefield - McMenamins
# URL: https://www.mcmenamins.com/events/275073-st-patricks-celebrations
# Snippet: The leprechauns are on our side, bringing us rainbows and merriment for St. Patrick's Day. Join us for multiple days of food & drink specials,...
#
# **6. Also, include practical details like location and maybe entry info. Let me double-check if these pubs are still operating and if their music nights are consistent. Since it's 2026, some info might have changed, but these are long-standing establishments. **
# Title: Concerts & Events
# URL: https://bigrailbrewing.com/events/
# Snippet: New music slated for mid-Spring 2026 promises to be both a departure from previous endeavors while holding fast to the core of the passion and performance...
#
# **7. **Live Session at The Irish Pub**  **
# Title: Mark your calendars for our next pub night on Friday, February 27 ...
# URL: https://www.facebook.com/irishculturalsocietyofcalgary/posts/mark-your-calendars-for-our-next-pub-night-on-friday-february-27-2026-join-us-fo/1224384506516240/
# Snippet: Mark your calendars for our next pub night on Friday, February 27, 2026. Join us for the pub quiz, Chase the Ace, and live music with 3 Piece...
#
# **8.  **
# Title: February 27 Holidays and Observances, Events, History, Recipe ...
# URL: https://www.holidays-and-observances.com/february-27.html
# Snippet: February 27 Information from the Holidays and Observances Website. **2026 Daily Holidays that fall on February 27, include:**. **2026 Weekly Holidays that include February 27, are:**. **2026 Monthly Holidays that include February 27, are:**. There are too many monthly holidays to include here, so pl...
#
# **9.  **
# Title: February 27 Holidays and Observances, Events, History, Recipe ...
# URL: https://www.holidays-and-observances.com/february-27.html
# Snippet: February 27 Information from the Holidays and Observances Website. **2026 Daily Holidays that fall on February 27, include:**. **2026 Weekly Holidays that include February 27, are:**. **2026 Monthly Holidays that include February 27, are:**. There are too many monthly holidays to include here, so pl...
#
# **10. No cover charge.  **
# Title: Special Guest - Electric Mushroom Friday February 27, 2026
# URL: https://nocovernightclubs.com/events/special-guest-electric-mushroom-friday-february-27-2026/
# Snippet: Use discount code NOCOVER for instant savings at checkout. Time. 02/27/2026 9:00 pm(GMT-08:00) ... No Cover Nightclubs © 2026 • Privacy Policy •...
#
# **11. **St. Patrick’s Day Preview at O’Donnell’s Irish Pub**  **
# Title: Shawn O'Donnells Irish Pub on Instagram: "St. Patrick's Day is just ...
# URL: https://www.instagram.com/p/CKUML91APZu/
# Snippet: We're excited to present O'Donnell's Irish Dinner & Plastic Paddies Show — a festive evening of delicious Irish food, laughter, music, and great...

# %% [markdown]
# ## Small test on Tavilly output structure

# %%
today_date = datetime.now().strftime("%B %d, %Y")

# %%
query = f'live irish music events at a pub in Barcelona tonight {today_date}'

# %%
print(query)
# Out:
# live irish music events at a pub in Barcelona tonight February 27, 2026

# %%
test_results = tavily.invoke({"query": query})

# %%
test_results
# Out:
# {'query': 'live irish music events at a pub in Barcelona tonight February 27, 2026',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://michaelcollinspubs.com/events-calendar/?mc_id=4957',
#    'title': 'Events Calendar | The Michael Collins Irish Pub',
#    'content': 'The best Irish Pub in Barcelona! Live Music, Sports, Traditional Irish Music ... 27February 27, 2026○○(2 events) · 28February 28, 2026○○(8 events). Follow Us',
#    'score': 0.9999808,
#    'raw_content': None},
#   {'url': 'https://www.tripadvisor.com/Attraction_Review-g187497-d23568894-Reviews-or10-The_Old_Irish_Pub_Barcelona-Barcelona_Catalonia.html',
#    'title': 'The Old Irish Pub Barcelona (2026) - All You MUST Know Before ...',
#    'content': '‣ Authentic Irish atmosphere ‣ Fantastic live music ‣ Sport events on big screens ‣ A broad selection of beer, liquor and cocktails ‣ Party and dancing on',
#    'score': 0.99995315,
#    'raw_content': None},
#   {'url': 'https://templebarbcn.com/en',
#    'title': 'Home - Temple Bar Irish Pub',
#    'content': 'Temple Bar Barcelona is a genuine Irish pub in the heart of the Gothic Quarter ... 27 FEB. 21:00. Temple Bar Ferran & Temple Bar Avinyó · Spanish La Liga.',
#    'score': 0.99986756,
#    'raw_content': None},
#   {'url': 'https://www.shazam.com/events/ciutat-vella-barcelona-spain/-/-/blues-2+hip-hoprap-18+pop-14',
#    'title': 'Find concerts by genres in Ciutat Vella | Shazam',
#    'content': 'Dirty Suc concert - Barcelona, Club Sauvage, Friday, February 27, 2026 ... Guy Hamilton concert - Barcelona, The Old Irish Pub, Monday, March 23,. Monday',
#    'score': 0.9993175,
#    'raw_content': None},
#   {'url': 'https://www.shazam.com/events/barri-g%C3%B2tic-barcelona-spain/-/-/%D1%85%D1%80%D0%B8%D1%81%D1%82%D0%B8%D0%B0%D0%BD%D1%81%D0%BA%D0%B0%D1%8F-%D0%BC%D1%83%D0%B7%D1%8B%D0%BA%D0%B0-%D0%B8-%D0%B3%D0%BE%D1%81%D0%BF%D0%B5%D0%BB-22+blues-2+country-6+muzyka-elektroniczna-7',
#    'title': 'Find concerts by genres in Barri Gòtic - Shazam',
#    'content': 'Afrosideral concert - Barcelona, Marula Café, Friday, February 27, 2026 ... Guy Hamilton concert - Barcelona, The Old Irish Pub, Monday, March 23,. Monday',
#    'score': 0.9992792,
#    'raw_content': None}],
#  'response_time': 0.98,
#  'request_id': 'a7afc2fe-1420-4d68-9048-b6f245192f94'}

# %%
# top result based on the score
test_results["results"][0]
# Out:
# {'url': 'https://michaelcollinspubs.com/events-calendar/?mc_id=4957',
#  'title': 'Events Calendar | The Michael Collins Irish Pub',
#  'content': 'The best Irish Pub in Barcelona! Live Music, Sports, Traditional Irish Music ... 27February 27, 2026○○(2 events) · 28February 28, 2026○○(8 events). Follow Us',
#  'score': 0.9999808,
#  'raw_content': None}
